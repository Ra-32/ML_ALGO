# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/placement (2).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# # Linear regression =regression mean there are output col is numerical;
#
#
# there are three types of LR
#
#
# 1.   **simple lr** = 1 input and 1 output
# 2.   **multiple lr**= more tahn 1 input
# 3.   **ploynomial lr**

# %% [markdown]
# # Simple LR
#
# y=mx+b
#
# m= slope =summation of i to n (xi-x.mean)*(yi-y.mean)/summation of i to n (xi-x.mean)2
#
# b=y_intercept = y.mean -m*x.mean

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.head()
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.780730147510384

# %%
m=lr.coef_ # m

# %%
b=lr.intercept_ # b

# %%
plt.scatter(x,y)
plt.plot(x_train,lr.predict(x_train),color='red')

# %%
x_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# Name: package, dtype: float64

# %%
m*8.58+b # y= mx+b
# Out:
# array([3.89111601])

# %%
m*4.57+b
# Out:
# array([1.6537286])
